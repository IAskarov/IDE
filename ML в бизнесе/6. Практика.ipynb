# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('shared_articles.csv')
df1 = pd.read_csv('users_interactions.csv')

# %%
df = df[df['eventType'] == 'CONTENT SHARED']
df.shape
# Out:
# (3047, 13)

# %%
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from lightfm import LightFM
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from lightfm.cross_validation import random_train_test_split
# ...

# %%
# !pip install scipy==1.10
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'C:\\Users\\askar\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\~cipy\\.libs\\libansari.54HGNEJBQIYZX5TZPCQGLNVIPFU6NWEX.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
# ...
#      -------------------------------------- 42.5/42.5 MB 646.1 kB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.1
#     Uninstalling scipy-1.8.1:
#       Successfully uninstalled scipy-1.8.1

# %%
from scipy.sparse import csr_matrix

# %%
pip install tensorflow
# Out:
# ...
#      -------------------------------------- 266.3/266.3 MB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.6/2.6 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 895.9/895.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.7/3.7 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.0/6.0 MB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 23.2/23.2 MB 871.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 439.2/439.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.5/126.5 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 743.6 kB/s eta 0:00:00
# ...

# %%
df1
# Out:
#         timestamp eventType            contentId             personId  \
# 0      1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1      1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2      1465416190      VIEW   310515487419366995 -1130272294246983140
# 3      1465413895    FOLLOW   310515487419366995   344280948527967603
# 4      1465412290      VIEW -7820640624231356730  -445337111692715325
# ...           ...       ...                  ...                  ...
# 72307  1485190425      LIKE -6590819806697898649 -9016528795238256703
# 72308  1485190425      VIEW -5813211845057621660   102305705598210278
# 72309  1485190072      VIEW -1999468346928419252 -9196668942822132778
# 72310  1485190434      VIEW -6590819806697898649 -9016528795238256703
# 72311  1485187988      VIEW  5669290109546991426  5713241217519616260
#
#                  sessionId                                          userAgent  \
# ...

# %%
event_type = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 2.5, 
   'FOLLOW': 3.0,
   'COMMENT CREATED': 4.0,  
}

# %%
df1['eventStrength'] = df1.eventType.apply(lambda x: event_type[x])
df1['eventStrength'].mean()
# Out:
# 1.2362885828078327

# %%
users_df = (
    df1
    .groupby(['personId', 'contentId'])
    .first()
    .reset_index()
    .groupby('personId').size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> users_df = (
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     df1
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     .groupby(['personId', 'contentId'])
# ...

# %%
users_df_5 = users_df[users_df >= 5].reset_index()[['personId']]

# %%
print(len(users_df_5))
# Out:
# 1140

# %%
int_from_users5_df = df1.loc[np.in1d(df1.personId,
            users_df_5)] #этот метод используется, если мы хотим найти  пересечение двух одномерных массивов NumPy
print(int_from_users5_df.shape)
# Out:
# (69868, 9)

# %%
int_from_users5_df
# Out:
#         timestamp eventType            contentId             personId  \
# 0      1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1      1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2      1465416190      VIEW   310515487419366995 -1130272294246983140
# 3      1465413895    FOLLOW   310515487419366995   344280948527967603
# 4      1465412290      VIEW -7820640624231356730  -445337111692715325
# ...           ...       ...                  ...                  ...
# 72307  1485190425      LIKE -6590819806697898649 -9016528795238256703
# 72308  1485190425      VIEW -5813211845057621660   102305705598210278
# 72309  1485190072      VIEW -1999468346928419252 -9196668942822132778
# 72310  1485190434      VIEW -6590819806697898649 -9016528795238256703
# 72311  1485187988      VIEW  5669290109546991426  5713241217519616260
#
#                  sessionId                                          userAgent  \
# ...

# %%
def smooth_user_preference(x):
    return math.log(1+x, 2)

# %%
full_df = (
    int_from_users5_df
    .groupby(['personId', 'contentId']).eventStrength.sum()
    .apply(smooth_user_preference)
    .reset_index().set_index(['personId', 'contentId'])
)
full_df['last_timestamp'] = (
    int_from_users5_df
    .groupby(['personId', 'contentId'])['timestamp'].max()
)
        
full_df['last_timestamp'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Ячейка 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> full_df = (
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     int_from_users5_df
# ...

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
model = TfidfVectorizer(stop_words='english')

# %%
data['description'] = data['description'].fillna('')

# %%
feature_matrix = model.fit_transform(data['description'])

# %%
feature_matrix.shape
# Out:
# (7787, 17905)

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(feature_matrix, feature_matrix)

# %%
indices = pd.Series(data.index,index=data['title']).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> indices = pd.Series(data.index,index=data['title']).drop_duplicates()
#
# NameError: name 'pd' is not defined

# %%
def get_recommendations(title):
    idx = indices[title]
    #вычисляем попарные коэффициенты косинусной близости
    scores = list(enumerate(cosine_sim[idx]))
    #сортируем фильмы на основании коэффициентов косинусной близости по убыванию
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    #выбираем десять наибольших значений косинусной близости; нулевую не берём, т. к. это тот же фильм
    scores =   scores[1:11]
    #забираем индексы
    ind_movie = [i[0] for i in scores]
    #возвращаем названия по индексам
    return data['title'].iloc[ind_movie]

# %%
get_recommendations('Balto')
# Out:
# 709                Balto 2: Wolf Quest
# 7446                           Vroomiz
# 1338    Chilling Adventures of Sabrina
# 7388                          Vampires
# 1770                          Dinotrux
# 2767                     Hold the Dark
# 5540                 Shanghai Fortress
# 4041                             Mercy
# 2582                       Half & Half
# 1365        Christmas in the Heartland
# Name: title, dtype: object

# %%
# !pip install surprise
# Out:
# ...
#   Using cached surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# ...
#   Using cached scikit-surprise-1.1.3.tar.gz (771 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): still running...
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for scikit-surprise
# Failed to build scikit-surprise
# ...
#   Running setup.py install for scikit-surprise: started
#   Running setup.py install for scikit-surprise: finished with status 'error'
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rompt-toolkit (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
# !pip install scikit-surprise
# Out:
# ...
#   Using cached scikit-surprise-1.1.3.tar.gz (771 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for scikit-surprise
# Failed to build scikit-surprise
# ...
#   Running setup.py install for scikit-surprise: started
#   Running setup.py install for scikit-surprise: finished with status 'error'
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rompt-toolkit (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\askar\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
from surprise import Dataset
from surprise import Reader
from surprise.dataset import BUILTIN_DATASETS #с помощью данного объекта мы можем использовать встроенные датасеты

data = Dataset.load_from_file(
    "u.data.txt",
    reader=Reader(line_format="user item rating timestamp", sep="\t"),
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Ячейка 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> from surprise import Dataset
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> from surprise import Reader
# ...

# %%
data = Dataset.load_from_file(
    "u.data.txt",
    reader=Reader(line_format="user item rating timestamp", sep="\t"),
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\My date\Skillfactory\Course\IDE\ML в бизнесе\6. Практика.ipynb Ячейка 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> data = Dataset.load_from_file(
#       <a href='vscode-notebook-cell:/e%3A/My%20date/Skillfactory/Course/IDE/ML%20%D0%B2%20%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/6.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a>     "u.data.txt",
# ...
